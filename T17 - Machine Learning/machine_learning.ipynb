# %% [markdown]
# # Machine Learning
# ## Compulsory task

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)    | Output     |
# | ---- | ----------- | ---------  |
# | 1.1  | gps-coordinates, weather | optimal speed |
# | 1.2  | age, language | movies that are likely to be liked, movies that are trendy for similar users |
# | 1.3  | the direction of the signature strokes, size of the signature in terms of area | fake warning |
# | 1.4  | the number of leukocytes, the presence of cough | the effectiveness of treatment with the drug |
#
# 1.1 These inputs allow the system to get a complete picture of the environment and the context of the vehicle's movement. Depending on the realities on the road and safety issues, the optimal speed may change to ensure an optimal response to the environment.
#
# 1.2 These inputs help to accommodate the users' language preferences and the tastes of the respective age group. Recommendation models use these characteristics to personalize recommendations.
#
# 1.3 This information is important for distinguishing individual signature features and identifying writing features. If the signature characteristics do not match the user's reference signature, then it may be fake.
#
# 1.4 The input data can act as an informative indicator to assess how successfully the patient responds to drug treatment.

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1 Classification - the task is to define a category: promotional or social emails, that is, to assign each email to a specific class, which is the task of classification.
# * 2.2 Regression - the task is to predict a numerical value - the stock price, that is, to predict a continuous numerical value, which is the task of regression.
# * 2.3 Classification - the task is to assign each animal image a specific class (species), thus, this is a classification task.
# * 2.4 Classification - the task is to assign patients to different categories based on the presence or absence of a particular disease, that is, to define a class (presence or absence of the disease), which is the task of classification.

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1 Unsupervised ML - it can be difficult to identify all possible types of anomalies before starting the simulation; unsupervised learning algorithms can help identify unknown anomalies without the need for specific models.
# * 3.2 Supervised ML - the task is to predict a continuous numerical value (lifetime value) that corresponds to the regression problem, so supervised learning algorithms are suitable solutions for such a problem.
# * 3.3 Unsupervised ML - the task is to group customers into similar classes based on certain characteristics (clustering), which can be done without predefined classes.
# * 3.4 Unsupervised ML - unsupervised learning can group similar posts or highlight key topics in unobserved data without predefined categories.

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# * 4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1 Inappropriate - since most transactions already have labels, it is best to use supervised learning techniques; semi-supervised learning will be less effective.
# * 4.2 Appropriate - since only a small part of the data has labels, semi-supervised learning can be used to exploit information from unlabeled samples.
# * 4.3 Inappropriate - since there is a large amount of labeled data (spam and non-spam), using supervised learning is more appropriate because you can use these labels to train effective models.
# * 4.4 Inappropriate - since there is complete financial and credit-related information, the best approach would be to use supervised learning to predict the probability of default, since much of the data already has relevant labels.
